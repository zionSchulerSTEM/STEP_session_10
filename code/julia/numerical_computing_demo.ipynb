# %%
Pkg.add("Symbolics")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed ArrayInterfaceStaticArrays ───── v0.1.4
#    Installed Calculus ─────────────────────── v0.5.1
#    Installed IrrationalConstants ──────────── v0.1.1
#    Installed DynamicPolynomials ───────────── v0.4.5
#    Installed RandomExtensions ─────────────── v0.4.3
#    Installed GPUArraysCore ────────────────── v0.1.2
#    Installed AutoHashEquals ───────────────── v0.2.0
#    Installed Transducers ──────────────────── v0.4.73
#    Installed Adapt ────────────────────────── v3.4.0
#    Installed TreeViews ────────────────────── v0.3.0
#    Installed DiffRules ────────────────────── v1.11.1
#    Installed DualNumbers ──────────────────── v0.6.8
#    Installed FunctionWrappersWrappers ─────── v0.1.0
#    Installed MultivariatePolynomials ──────── v0.4.6
#    Installed Rmath ────────────────────────── v0.7.0
#    Installed IntegerMathUtils ─────────────── v0.1.0
# ...

# %%
using Pkg
